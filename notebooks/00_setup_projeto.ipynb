# %%
#DANDO ACESSO AO DRIVE

from google.colab import drive

drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/
# Out:
# /content/drive/MyDrive

# %%
#NAVEGANDO ATÉ A PASTA DESTINO

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# CLONAR REPOSITÓRIO DO GIT PARA O DRIVE USANDO O TOKEN DO GITHUB

# !git clone https://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@github.com/karine94/cafeicultura-varginha-analytics.git
# Out:
# Cloning into 'cafeicultura-varginha-analytics'...
# remote: Enumerating objects: 5, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 5 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (5/5), done.

# %%
# ENTRAR NA PASTA E CONFIGURAR O AUTOR DAS ALTERAÇÕES

# %cd cafeicultura-varginha-analytics

# !git config user.name "Karine Almeida"
# !git config user.email "karinealmeida.kca@gmail.com"
# Out:
# /content/drive/MyDrive/cafeicultura-varginha-analytics

# %%
# CRIANDO A LISTA DE PASTAS DO PROJETO

import os

# Lista de pastas do projeto
pastas = [
    "data/raw",  # Dados brutos (ex: INMET, IBGE) sem alteração
    "data/processed",  # Dados limpos e prontos para modelagem
    "notebooks",  # Notebooks para análises e gráficos
    "src",  # Scripts e funções Python reutilizáveis
    "models",  # Modelos preditivos treinados e salvos
]

# Criação de pasta e adição do arquivo .gitkeep
for pasta in pastas:
    os.makedirs(pasta, exist_ok=True)
    with open(os.path.join(pasta, ".gitkeep"), "w") as f:
        pass

# %%
# ENVIANDO ESTRUTURA PARA GITHUB (VERSIONAMENTO)

# !git status
# !git add .
# !git commit -m "estrutura: Diretórios iniciais do projeto"
# !git push origin main
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	data/
# 	models/
# 	notebooks/
# 	src/
#
# nothing added to commit but untracked files present (use "git add" to track)
# [main a8beea6] estrutura: Diretórios iniciais do projeto
#  5 files changed, 0 insertions(+), 0 deletions(-)
#  create mode 100644 data/processed/.gitkeep
#  create mode 100644 data/raw/.gitkeep
#  create mode 100644 models/.gitkeep
#  create mode 100644 notebooks/.gitkeep
#  create mode 100644 src/.gitkeep
# Enumerating objects: 6, done.
# Counting objects: 100% (6/6), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (5/5), 519 bytes | 64.00 KiB/s, done.
# Total 5 (delta 0), reused 0 (delta 0), pack-reused 0
# To https://github.com/karine94/cafeicultura-varginha-analytics.git
#    423cf04..a8beea6  main -> main

# %%
# Lista de bibliotecas essenciais para o projeto
requisitos = """pandas
numpy
matplotlib
seaborn
requests
scikit-learn
"""

with open("requirements.txt", "w") as f:
    f.write(requisitos.strip())

print("Arquivo requirements.txt gerado com sucesso!")


# adicionando alterações no github

# !git add requirements.txt
# !git commit -m "docs: adiciona dependencias iniciais do projeto"
# !git push origin main
# Out:
# Arquivo requirements.txt gerado com sucesso!
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	notebooks/00_setup_projeto.ipynb
#
# nothing added to commit but untracked files present (use "git add" to track)
# Everything up-to-date
